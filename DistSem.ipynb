# %%
import gensim
from gensim.models import KeyedVectors
#загрузим вектора, построенные cbow на навостном корпусе
vectors = KeyedVectors.load('D:/PyProjects/test/model1_cbow_vectors._')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1167: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# Найдем самые близкие слова к слову "чай"

# %%
print(vectors.most_similar(positive=['чай']))
# Out:
# [('чай,', 0.8797088861465454), ('кофе', 0.8467174768447876), ('напиток', 0.8238502144813538), ('ароматный', 0.8034936189651489), ('шоколад', 0.8029804229736328), ('мед', 0.7999616861343384), ('квас', 0.7983540296554565), ('лимоном', 0.7963413000106812), ('кефир', 0.7932333946228027), ('лимонад', 0.7909421920776367)]

# %% [markdown]
# Найдите самые близкие слова к словам
# (1) "вкусный"
# (2) "потому_что"
# (3) "так_как"
# (4) "это_привело_к"

# %%
print(vectors.most_similar(positive=['чай', 'кофе']))
# Out:
# [('чай,', 0.8813067078590393), ('кофе,', 0.8809810876846313), ('чая', 0.8666861057281494), ('шоколад', 0.8229880332946777), ('кефир', 0.8153190612792969), ('чая,', 0.8147156238555908), ('коньяк', 0.814572274684906), ('напиток', 0.812443196773529), ('лимоном', 0.8123627305030823), ('лимонад', 0.8108313083648682)]

# %%
print(vectors.most_similar(positive=['чай'], topn=50))
# Out:
# [('чай,', 0.8797088861465454), ('кофе', 0.8467174768447876), ('напиток', 0.8238502144813538), ('ароматный', 0.8034936189651489), ('шоколад', 0.8029804229736328), ('мед', 0.7999616861343384), ('квас', 0.7983540296554565), ('лимоном', 0.7963413000106812), ('кефир', 0.7932333946228027), ('лимонад', 0.7909421920776367), ('свежезаваренный', 0.7893812656402588), ('виноградный', 0.7893280386924744), ('морковный', 0.7888327836990356), ('кофе,', 0.788389265537262), ('сок,', 0.7881327271461487), ('свекольный', 0.7879344820976257), ('бергамотом', 0.7853150367736816), ('некрепкий', 0.7851294875144958), ('плов', 0.7850605249404907), ('изюмом', 0.7830196619033813), ('несладкий', 0.7792738676071167), ('коньяк', 0.7776407599449158), ('аперитив', 0.7756319046020508), ('свежевыжатый', 0.7754777073860168), ('квас,', 0.7741230726242065), ('глинтвейн', 0.7718431949615479), ('чая', 0.7713984251022339), ('ром,', 0.7708854675292969), ('йогурт', 0.7705628871917725), ('йогурт,', 0.7703593373298645), ('лимонны
# ...

# %% [markdown]
# Получите топ 20 для глагола "привело", прилагательного "вкусный"

# %% [markdown]
# Вычислите, какие слова ближе: чай - кола, чай - кофе; вкусный - отличный, вкусный - отвратительный, вкусный - еда
# Какое слово лишнее (функция: vectors.doesnt_match) - "колбаса сыр кофе сосиска
